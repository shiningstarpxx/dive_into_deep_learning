# %%
''' 
因此，与端到端（像素到分类）系统相比，经典的计算机视觉处理流程更像是这样的：

1. 获取有趣的数据集。在早期，这些数据集需要昂贵的传感器。例如，1994年的Apple QuickTake 100拥有高达0.3百万像素（VGA）的分辨率，能够存储多达8张图像，售价为1000美元。

2. 使用基于光学、几何学、其他分析工具以及偶尔基于幸运的研究生的意外发现的手工特征预处理数据集。

3. 通过一套标准的特征提取器（如SIFT（尺度不变特征变换）（Lowe，2004）、SURF（加速鲁棒特征）（Bay等人，2006）或其他手动调整的处理流程）处理数据。时至今日，OpenCV仍然提供SIFT提取器！

4. 将所得到的表示结果输入到您喜欢的分类器中，可能是一个线性模型或者核方法，以训练分类器。

如果您与机器学习研究人员交谈，他们会告诉您机器学习既重要又美丽。优雅的理论证明了各种分类器的性质（Boucheron等人，2005），凸优化（Boyd和Vandenberghe，2004）已成为获得这些分类器的主要方法。
机器学习领域正在蓬勃发展，严谨而非常实用。然而，如果您与计算机视觉研究人员交谈，您会听到一个完全不同的故事。他们会告诉您，图像识别的肮脏真相是特征、
几何（Hartley和Zisserman，2000，Hartley和Kahl，2009）和工程，而不是新颖的学习算法，推动了进步。计算机视觉研究人员有充分的理由相信，相对于任何学习算法，稍微更大或更干净的数据集或稍微改进的特征提取流程对最终准确性的影响要大得多。
'''
